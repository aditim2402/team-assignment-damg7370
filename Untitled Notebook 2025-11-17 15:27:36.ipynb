# %%
# 1️⃣ List the folder – must show "customer_data_1 (1).json"
display(dbutils.fs.ls("/Volumes/workspace/damg7370/datastore/schema_drift/schema_drift_fresh"))

# %%
# 2️⃣ See the raw text of the file
raw = spark.read.text("/Volumes/workspace/damg7370/datastore/schema_drift/schema_drift_fresh")
raw.show(truncate=False)

# %%
# 3️⃣ Try a simple JSON read (no Auto Loader)
test_df = spark.read \
    .format("json") \
    .option("multiLine", "true") \
    .load("/Volumes/workspace/damg7370/datastore/schema_drift/schema_drift_fresh")

test_df.printSchema()
test_df.show(5)

# %%
# %sql
USE CATALOG workspace;
USE SCHEMA damg7370;

# %%
# %sql
SELECT * 
FROM workspace.damg7370.demo_cust_bronze_sd 
LIMIT 20;

# %%
# %sql
SELECT
  COUNT(*)                                       AS total_rows,
  SUM(CASE WHEN _rescued_data IS NOT NULL THEN 1 ELSE 0 END) AS rescued_rows
FROM demo_cust_bronze_sd;

# %%
# %sql
SELECT * FROM demo_cust_silver_rescue LIMIT 20;

# %%
path = "/Volumes/workspace/damg7370/datastore/schema_drift/addnew_input"

display(dbutils.fs.ls(path))

# %%
# %sql
SELECT * FROM workspace.damg7370.demo_cust_bronze_addcols_sd;

# %%
# %sql
SELECT * FROM workspace.damg7370.demo_cust_silver_addcols_sd;
